# %%
# 🚧 01_build_graph.ipynb — Road Network Graph Construction

# ⭐ Purpose of this notebook

# Load cleaned road data

# Convert roads into a NetworkX graph

# Add length (meters) as an edge attribute

# Save the graph for later routing

# %%
# --- BUILD ROAD NETWORK GRAPH ---

import geopandas as gpd
